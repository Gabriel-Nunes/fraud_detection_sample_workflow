# %% [markdown]
# # Detecting Fraud in Bank Transactions
#
# Creating a predictive system to detect fraudulent transactions in bank datasets.
#
# ## 1. Importing the libraries

# %%
# Basic packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# Data pre-processing packages
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# Machine learning packages
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

# %% [markdown]
# # 2. Creating fake data

# %% [markdown]
# # 3. Preprocessing

# %% [markdown]
# Data normalization, outliers, missing values, feature selection.

# %% [markdown]
# # 4. Loading data

# %%
#df = pd.read_csv('data/transferencias.csv')
df = pd.read_csv('data/bank_transactions.csv')
df
# Out:
#          Timestamp  country    city  district  postal_code  ip_address  \
# 0           0.0000  -1.3598 -0.0728    2.5363       1.3782     -0.3383
# 1           0.0000   1.1919  0.2662    0.1665       0.4482      0.0600
# 2           1.0000  -1.3584 -1.3402    1.7732       0.3798     -0.5032
# 3           1.0000  -0.9663 -0.1852    1.7930      -0.8633     -0.0103
# 4           2.0000  -1.1582  0.8777    1.5487       0.4030     -0.4072
# ...            ...      ...     ...       ...          ...         ...
# 284802 172786.0000 -11.8811 10.0718   -9.8348      -2.0667     -5.3645
# 284803 172787.0000  -0.7328 -0.0551    2.0350      -0.7386      0.8682
# 284804 172788.0000   1.9196 -0.3013   -3.2496      -0.5578      2.6305
# 284805 172788.0000  -0.2404  0.5305    0.7025       0.6898     -0.3780
# 284806 172792.0000  -0.5334 -0.1897    0.7033      -0.5063     -0.0125
#
#            day    hour  minute  operating_system  amount  background  \
# 0       0.4624  0.2396  0.0987            0.3638  0.0908     -0.5516
# 1      -0.0824 -0.0788  0.0851           -0.2554 -0.1670      1.6127
# 2       1.8005  0.7915  0.2477           -1.5147  0.2076      0.6245
# 3       1.2472  0.2376  0.3774           -1.3870 -0.0550     -0.2265
# 4       0.0959  0.5929 -0.2705            0.8177  0.7531     -0.8228
# ...        ...     ...     ...               ...     ...         ...
# 284802 -2.6068 -4.9182  7.3053            1.9144  4.3562     -1.5931
# 284803  1.0584  0.0243  0.2949            0.5848 -0.9759     -0.1502
# 284804  3.0313 -0.2968  0.7084            0.4325 -0.4848      0.4116
# 284805  0.6237 -0.6862  0.6791            0.3921 -0.3991     -1.9338
# 284806 -0.6496  1.5770 -0.4147            0.4862 -0.9154     -1.0405
#
#         complaints  transaction_count  credit  global_limit  credit_type  \
# 0          -0.6178            -0.9914 -0.3112        1.4682      -0.4704
# 1           1.0652             0.4891 -0.1438        0.6356       0.4639
# 2           0.0661             0.7173 -0.1659        2.3459      -2.8901
# 3           0.1782             0.5078 -0.2879       -0.6314      -1.0596
# 4           0.5382             1.3459 -1.1197        0.1751      -0.4514
# ...            ...                ...     ...           ...          ...
# 284802      2.7119            -0.6893  4.6269       -0.9245       1.1076
# 284803      0.9158             1.2148 -0.6751        1.1649      -0.7118
# 284804      0.0631            -0.1837 -0.5106        1.3293       0.1407
# 284805     -0.9629            -1.0421  0.4496        1.9626      -0.6086
# 284806     -0.0315            -0.1881 -0.0843        0.0413      -0.3026
#
#         merchant  accounts   loans  browser  android     ios  purchases  \
# 0         0.2080    0.0258  0.4040   0.2514  -0.0183  0.2778    -0.1105
# 1        -0.1148   -0.1834 -0.1458  -0.0691  -0.2258 -0.6387     0.1013
# 2         1.1100   -0.1214 -2.2619   0.5250   0.2480  0.7717     0.9094
# 3        -0.6841    1.9658 -1.2326  -0.2080  -0.1083  0.0053    -0.1903
# 4        -0.2370   -0.0382  0.8035   0.4085  -0.0094  0.7983    -0.1375
# ...          ...       ...     ...      ...      ...     ...        ...
# 284802    1.9917    0.5106 -0.6829   1.4758   0.2135  0.1119     1.0145
# 284803   -0.0257   -1.2212 -1.5456   0.0596   0.2142  0.9244     0.0125
# 284804    0.3135    0.3957 -0.5773   0.0014   0.2320  0.5782    -0.0375
# 284805    0.5099    1.1140  2.8978   0.1274   0.2652  0.8000    -0.1633
# 284806   -0.6604    0.1674 -0.2561   0.3829   0.2611  0.6431     0.3768
#
#         browsing_history  relationship  security_index  transaction_time  \
# 0                 0.0669        0.1285         -0.1891            0.1336
# 1                -0.3398        0.1672          0.1259           -0.0090
# 2                -0.6893       -0.3276         -0.1391           -0.0554
# 3                -1.1756        0.6474         -0.2219            0.0627
# 4                 0.1413       -0.2060          0.5023            0.2194
# ...                  ...           ...             ...               ...
# 284802           -0.5093        1.4368          0.2500            0.9437
# 284803           -1.0162       -0.6066         -0.3953            0.0685
# 284804            0.6401        0.2657         -0.0874            0.0045
# 284805            0.1232       -0.5692          0.5467            0.1088
# 284806            0.0088       -0.4736         -0.8183           -0.0024
#
#         credit_limit  balance_history  Target
# 0            -0.0211         149.6200       0
# 1             0.0147           2.6900       0
# 2            -0.0598         378.6600       0
# 3             0.0615         123.5000       0
# 4             0.2152          69.9900       0
# ...              ...              ...     ...
# 284802        0.8237           0.7700       0
# 284803       -0.0535          24.7900       0
# 284804       -0.0266          67.8800       0
# 284805        0.1045          10.0000       0
# 284806        0.0136         217.0000       0
#
# [284807 rows x 31 columns]

# %% [markdown]
# # 5. Exploratory Data Analysis

# %% [markdown]
# First, let's check for missing values in the dataset.

# %%
# Checking for missing values
print(df.isna().sum())
# Out:
# Timestamp            0
# country              0
# city                 0
# district             0
# postal_code          0
# ip_address           0
# day                  0
# hour                 0
# minute               0
# operating_system     0
# amount               0
# background           0
# complaints           0
# transaction_count    0
# credit               0
# global_limit         0
# credit_type          0
# merchant             0
# accounts             0
# loans                0
# browser              0
# android              0
# ios                  0
# purchases            0
# browsing_history     0
# relationship         0
# security_index       0
# transaction_time     0
# credit_limit         0
# balance_history      0
# Target               0
# dtype: int64

# %% [markdown]
# Great! There's no missing values in the dataset.
#
# Now, let's check the distribution of the target variable.

# %%
display(df['Target'].value_counts())
px.bar(df['Target'].value_counts(), )
# Out:
# Target
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
(len(df[df['Target'] == 1]) / len(df['Target'])) * 100
# Out:
# 0.1727485630620034

# %% [markdown]
# As we can see, the dataset is extremely imbalanced, with only 0.17% of the transactions being frauds.
#
# So, further on we'll need to perform a resampling to balance the dataset.
#
# We also need to know the variables correlation to the target variable:

# %%
df.corr()['Target'].sort_values(ascending=False)
# Out:
# Target               1.0000
# background           0.1549
# postal_code          0.1334
# city                 0.0913
# android              0.0404
# loans                0.0348
# browser              0.0201
# minute               0.0199
# transaction_time     0.0176
# credit_limit         0.0095
# balance_history      0.0056
# security_index       0.0045
# relationship         0.0033
# ios                  0.0008
# purchases           -0.0027
# global_limit        -0.0042
# transaction_count   -0.0046
# browsing_history    -0.0072
# Timestamp           -0.0123
# day                 -0.0436
# ip_address          -0.0950
# operating_system    -0.0977
# country             -0.1013
# accounts            -0.1115
# hour                -0.1873
# district            -0.1930
# credit_type         -0.1965
# amount              -0.2169
# complaints          -0.2606
# credit              -0.3025
# merchant            -0.3265
# Name: Target, dtype: float64

# %% [markdown]
# Notice that "postal code" and "background" are the most important features for fraud detection.

# %% [markdown]
# Let's a more holistic analysis between the features of the dataset.

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1029a_row0_col0, #T_1029a_row1_col1, #T_1029a_row2_col2, #T_1029a_row3_col3, #T_1029a_row4_col4, #T_1029a_row5_col5, #T_1029a_row6_col6, #T_1029a_row7_col7, #T_1029a_row8_col8, #T_1029a_row9_col9, #T_1029a_row10_col10, #T_1029a_row11_col11, #T_1029a_row12_col12, #T_1029a_row13_col13, #T_1029a_row14_col14, #T_1029a_row15_col15, #T_1029a_row16_col16, #T_1029a_row17_col17, #T_1029a_row18_col18, #T_1029a_row19_col19, #T_1029a_row20_col20, #T_1029a_row21_col21, #T_1029a_row22_col22, #T_1029a_row23_col23, #T_1029a_row24_col24, #T_1029a_row25_col25, #T_1029a_row26_col26, #T_1029a_row27_col27, #T_1029a_row28_col28, #T_1029a_row29_col29, #T_1029a_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col1, #T_1029a_row1_col5, #T_1029a_row2_col5, #T_1029a_row3_col5, #T_1029a_row4_col5, #T_1029a_row6_col5, #T_1029a_row7_col5, #T_1029a_row8_col5, #T_1029a_row8_col29, #T_1029a_row9_col5, #T_1029a_row10_col5, #T_1029a_row10_col29, #T_1029a_row11_col5, #T_1029a_row12_col5, #T_1029a_row13_col5, #T_1029a_row14_col5, #T_1029a_row15_col5, #T_1029a_row16_col5, #T_1029a_row17_col5, #T_1029a_row18_col5, #T_1029a_row19_col5, #T_1029a_row20_col5, #T_1029a_row21_col5, #T_1029a_row22_col5, #T_1029a_row23_col5, #T_1029a_row24_col5, #T_1029a_row25_col5, #T_1029a_row26_col5, #T_1029a_row27_col5, #T_1029a_row28_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1029a_row0_col2, #T_1029a_row0_col29, #T_1029a_row12_col29 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_1029a_row0_col3, #T_1029a_row0_col4, #T_1029a_row0_col6, #T_1029a_row0_col11, #T_1029a_row0_col13, #T_1029a_row0_col15, #T_1029a_row0_col20, #T_1029a_row0_col24, #T_1029a_row0_col25, #T_1029a_row0_col26, #T_1029a_row0_col27, #T_1029a_row0_col28, #T_1029a_row1_col21, #T_1029a_row2_col21, #T_1029a_row2_col29, #T_1029a_row3_col0, #T_1029a_row3_col21, #T_1029a_row4_col21, #T_1029a_row5_col21, #T_1029a_row6_col21, #T_1029a_row7_col21, #T_1029a_row8_col21, #T_1029a_row9_col21, #T_1029a_row10_col21, #T_1029a_row11_col21, #T_1029a_row12_col21, #T_1029a_row13_col21, #T_1029a_row14_col21, #T_1029a_row15_col21, #T_1029a_row16_col21, #T_1029a_row17_col21, #T_1029a_row17_col30, #T_1029a_row18_col21, #T_1029a_row19_col21, #T_1029a_row20_col21, #T_1029a_row22_col21, #T_1029a_row23_col21, #T_1029a_row24_col21, #T_1029a_row25_col21, #T_1029a_row26_col21, #T_1029a_row27_col21, #T_1029a_row28_col21, #T_1029a_row29_col1, #T_1029a_row29_col2, #T_1029a_row29_col5, #T_1029a_row29_col8, #T_1029a_row29_col19, #T_1029a_row29_col22, #T_1029a_row29_col23, #T_1029a_row30_col7, #T_1029a_row30_col9, #T_1029a_row30_col10, #T_1029a_row30_col12, #T_1029a_row30_col14, #T_1029a_row30_col16, #T_1029a_row30_col17, #T_1029a_row30_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_1029a_row0_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col8, #T_1029a_row1_col6, #T_1029a_row1_col13, #T_1029a_row1_col22, #T_1029a_row2_col6, #T_1029a_row2_col13, #T_1029a_row2_col22, #T_1029a_row3_col6, #T_1029a_row3_col13, #T_1029a_row3_col22, #T_1029a_row4_col6, #T_1029a_row4_col13, #T_1029a_row4_col22, #T_1029a_row5_col6, #T_1029a_row5_col13, #T_1029a_row5_col22, #T_1029a_row6_col13, #T_1029a_row6_col22, #T_1029a_row7_col6, #T_1029a_row7_col13, #T_1029a_row7_col22, #T_1029a_row8_col6, #T_1029a_row8_col13, #T_1029a_row8_col22, #T_1029a_row9_col6, #T_1029a_row9_col13, #T_1029a_row9_col22, #T_1029a_row10_col6, #T_1029a_row10_col13, #T_1029a_row10_col22, #T_1029a_row11_col6, #T_1029a_row11_col13, #T_1029a_row11_col22, #T_1029a_row12_col6, #T_1029a_row12_col13, #T_1029a_row12_col22, #T_1029a_row13_col6, #T_1029a_row13_col22, #T_1029a_row14_col6, #T_1029a_row14_col13, #T_1029a_row14_col22, #T_1029a_row15_col6, #T_1029a_row15_col13, #T_1029a_row15_col22, #T_1029a_row16_col6, #T_1029a_row16_col13, #T_1029a_row16_col22, #T_1029a_row17_col6, #T_1029a_row17_col13, #T_1029a_row17_col22, #T_1029a_row18_col6, #T_1029a_row18_col13, #T_1029a_row18_col22, #T_1029a_row19_col6, #T_1029a_row19_col13, #T_1029a_row19_col22, #T_1029a_row20_col6, #T_1029a_row20_col13, #T_1029a_row20_col22, #T_1029a_row21_col6, #T_1029a_row21_col13, #T_1029a_row21_col22, #T_1029a_row22_col6, #T_1029a_row22_col13, #T_1029a_row23_col6, #T_1029a_row23_col13, #T_1029a_row23_col22, #T_1029a_row24_col6, #T_1029a_row24_col13, #T_1029a_row24_col22, #T_1029a_row25_col6, #T_1029a_row25_col13, #T_1029a_row25_col22, #T_1029a_row26_col6, #T_1029a_row26_col13, #T_1029a_row26_col22, #T_1029a_row27_col6, #T_1029a_row27_col13, #T_1029a_row27_col22, #T_1029a_row28_col6, #T_1029a_row28_col13, #T_1029a_row28_col22, #T_1029a_row30_col22 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col9, #T_1029a_row0_col19 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col10, #T_1029a_row1_col12, #T_1029a_row2_col12, #T_1029a_row3_col12, #T_1029a_row4_col12, #T_1029a_row5_col12, #T_1029a_row6_col12, #T_1029a_row7_col12, #T_1029a_row8_col12, #T_1029a_row9_col12, #T_1029a_row10_col12, #T_1029a_row11_col12, #T_1029a_row13_col12, #T_1029a_row14_col12, #T_1029a_row15_col12, #T_1029a_row16_col12, #T_1029a_row17_col12, #T_1029a_row18_col12, #T_1029a_row19_col12, #T_1029a_row20_col12, #T_1029a_row21_col12, #T_1029a_row22_col12, #T_1029a_row23_col12, #T_1029a_row24_col12, #T_1029a_row25_col12, #T_1029a_row26_col12, #T_1029a_row27_col12, #T_1029a_row28_col12 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col12, #T_1029a_row22_col29 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_1029a_row0_col14, #T_1029a_row1_col7, #T_1029a_row2_col7, #T_1029a_row3_col7, #T_1029a_row4_col7, #T_1029a_row5_col7, #T_1029a_row6_col7, #T_1029a_row8_col7, #T_1029a_row9_col7, #T_1029a_row10_col7, #T_1029a_row11_col7, #T_1029a_row12_col7, #T_1029a_row13_col7, #T_1029a_row14_col7, #T_1029a_row15_col7, #T_1029a_row16_col7, #T_1029a_row17_col7, #T_1029a_row18_col7, #T_1029a_row19_col7, #T_1029a_row20_col7, #T_1029a_row21_col7, #T_1029a_row22_col7, #T_1029a_row23_col7, #T_1029a_row24_col7, #T_1029a_row25_col7, #T_1029a_row26_col7, #T_1029a_row27_col7, #T_1029a_row28_col7, #T_1029a_row30_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col16, #T_1029a_row5_col30, #T_1029a_row9_col30 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col17, #T_1029a_row1_col25, #T_1029a_row2_col25, #T_1029a_row3_col25, #T_1029a_row4_col25, #T_1029a_row5_col25, #T_1029a_row6_col25, #T_1029a_row7_col25, #T_1029a_row8_col25, #T_1029a_row9_col25, #T_1029a_row10_col25, #T_1029a_row11_col25, #T_1029a_row12_col25, #T_1029a_row13_col25, #T_1029a_row14_col25, #T_1029a_row15_col25, #T_1029a_row16_col25, #T_1029a_row17_col25, #T_1029a_row18_col25, #T_1029a_row19_col25, #T_1029a_row20_col25, #T_1029a_row21_col25, #T_1029a_row22_col25, #T_1029a_row23_col25, #T_1029a_row24_col25, #T_1029a_row26_col25, #T_1029a_row27_col25, #T_1029a_row28_col25 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col18 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col21, #T_1029a_row30_col26 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col22, #T_1029a_row1_col11, #T_1029a_row1_col29, #T_1029a_row2_col11, #T_1029a_row3_col11, #T_1029a_row4_col11, #T_1029a_row5_col11, #T_1029a_row6_col11, #T_1029a_row7_col11, #T_1029a_row8_col11, #T_1029a_row9_col11, #T_1029a_row10_col11, #T_1029a_row12_col11, #T_1029a_row13_col11, #T_1029a_row14_col11, #T_1029a_row15_col11, #T_1029a_row16_col11, #T_1029a_row17_col11, #T_1029a_row18_col11, #T_1029a_row19_col11, #T_1029a_row20_col11, #T_1029a_row21_col11, #T_1029a_row22_col11, #T_1029a_row23_col11, #T_1029a_row24_col11, #T_1029a_row25_col11, #T_1029a_row26_col11, #T_1029a_row27_col11, #T_1029a_row28_col11, #T_1029a_row29_col11, #T_1029a_row29_col12 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_1029a_row0_col23, #T_1029a_row29_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1029a_r

# %% [markdown]
# This overview is important to detect interdependencies between variables and understand the data distribution. In this case, we can see that our most interesting variables are does not have a strong correlation with each other or with other variables. This could gave us a multicollinarity problem.

# %% [markdown]
# # 6. Preparing the data for the models

# %% [markdown]
# As we saw in the previous notebook, the dataset is imbalanced, with only 0.1% of the transactions being fraudulent. This is a common issue in fraud detection, and it requires special attention when building the model.
#
# To address this issue, we can use a variety of techniques, such as oversampling the minority class, undersampling the majority class, or using a combination of both. In this notebook, we will use oversampling to balance the dataset.
#
# We will use the SMOTE (Synthetic Minority Over-sampling Technique) algorithm to oversample the minority class. SMOTE works by creating synthetic examples of the minority class by interpolating between existing examples. This can help to balance the dataset and improve the performance of the model.
#
# First, we will split the dataset into training and testing sets. We will use 70% of the data for training and 30% for testing.

# %% [markdown]
# ### Spliting data into train and test
# Setting our explanatory variables:

# %%
X = df.drop(['Target'], axis=1)
X
# Out:
#          Timestamp  country    city  district  postal_code  ip_address  \
# 0           0.0000  -1.3598 -0.0728    2.5363       1.3782     -0.3383
# 1           0.0000   1.1919  0.2662    0.1665       0.4482      0.0600
# 2           1.0000  -1.3584 -1.3402    1.7732       0.3798     -0.5032
# 3           1.0000  -0.9663 -0.1852    1.7930      -0.8633     -0.0103
# 4           2.0000  -1.1582  0.8777    1.5487       0.4030     -0.4072
# ...            ...      ...     ...       ...          ...         ...
# 284802 172786.0000 -11.8811 10.0718   -9.8348      -2.0667     -5.3645
# 284803 172787.0000  -0.7328 -0.0551    2.0350      -0.7386      0.8682
# 284804 172788.0000   1.9196 -0.3013   -3.2496      -0.5578      2.6305
# 284805 172788.0000  -0.2404  0.5305    0.7025       0.6898     -0.3780
# 284806 172792.0000  -0.5334 -0.1897    0.7033      -0.5063     -0.0125
#
#            day    hour  minute  operating_system  amount  background  \
# 0       0.4624  0.2396  0.0987            0.3638  0.0908     -0.5516
# 1      -0.0824 -0.0788  0.0851           -0.2554 -0.1670      1.6127
# 2       1.8005  0.7915  0.2477           -1.5147  0.2076      0.6245
# 3       1.2472  0.2376  0.3774           -1.3870 -0.0550     -0.2265
# 4       0.0959  0.5929 -0.2705            0.8177  0.7531     -0.8228
# ...        ...     ...     ...               ...     ...         ...
# 284802 -2.6068 -4.9182  7.3053            1.9144  4.3562     -1.5931
# 284803  1.0584  0.0243  0.2949            0.5848 -0.9759     -0.1502
# 284804  3.0313 -0.2968  0.7084            0.4325 -0.4848      0.4116
# 284805  0.6237 -0.6862  0.6791            0.3921 -0.3991     -1.9338
# 284806 -0.6496  1.5770 -0.4147            0.4862 -0.9154     -1.0405
#
#         complaints  transaction_count  credit  global_limit  credit_type  \
# 0          -0.6178            -0.9914 -0.3112        1.4682      -0.4704
# 1           1.0652             0.4891 -0.1438        0.6356       0.4639
# 2           0.0661             0.7173 -0.1659        2.3459      -2.8901
# 3           0.1782             0.5078 -0.2879       -0.6314      -1.0596
# 4           0.5382             1.3459 -1.1197        0.1751      -0.4514
# ...            ...                ...     ...           ...          ...
# 284802      2.7119            -0.6893  4.6269       -0.9245       1.1076
# 284803      0.9158             1.2148 -0.6751        1.1649      -0.7118
# 284804      0.0631            -0.1837 -0.5106        1.3293       0.1407
# 284805     -0.9629            -1.0421  0.4496        1.9626      -0.6086
# 284806     -0.0315            -0.1881 -0.0843        0.0413      -0.3026
#
#         merchant  accounts   loans  browser  android     ios  purchases  \
# 0         0.2080    0.0258  0.4040   0.2514  -0.0183  0.2778    -0.1105
# 1        -0.1148   -0.1834 -0.1458  -0.0691  -0.2258 -0.6387     0.1013
# 2         1.1100   -0.1214 -2.2619   0.5250   0.2480  0.7717     0.9094
# 3        -0.6841    1.9658 -1.2326  -0.2080  -0.1083  0.0053    -0.1903
# 4        -0.2370   -0.0382  0.8035   0.4085  -0.0094  0.7983    -0.1375
# ...          ...       ...     ...      ...      ...     ...        ...
# 284802    1.9917    0.5106 -0.6829   1.4758   0.2135  0.1119     1.0145
# 284803   -0.0257   -1.2212 -1.5456   0.0596   0.2142  0.9244     0.0125
# 284804    0.3135    0.3957 -0.5773   0.0014   0.2320  0.5782    -0.0375
# 284805    0.5099    1.1140  2.8978   0.1274   0.2652  0.8000    -0.1633
# 284806   -0.6604    0.1674 -0.2561   0.3829   0.2611  0.6431     0.3768
#
#         browsing_history  relationship  security_index  transaction_time  \
# 0                 0.0669        0.1285         -0.1891            0.1336
# 1                -0.3398        0.1672          0.1259           -0.0090
# 2                -0.6893       -0.3276         -0.1391           -0.0554
# 3                -1.1756        0.6474         -0.2219            0.0627
# 4                 0.1413       -0.2060          0.5023            0.2194
# ...                  ...           ...             ...               ...
# 284802           -0.5093        1.4368          0.2500            0.9437
# 284803           -1.0162       -0.6066         -0.3953            0.0685
# 284804            0.6401        0.2657         -0.0874            0.0045
# 284805            0.1232       -0.5692          0.5467            0.1088
# 284806            0.0088       -0.4736         -0.8183           -0.0024
#
#         credit_limit  balance_history
# 0            -0.0211         149.6200
# 1             0.0147           2.6900
# 2            -0.0598         378.6600
# 3             0.0615         123.5000
# 4             0.2152          69.9900
# ...              ...              ...
# 284802        0.8237           0.7700
# 284803       -0.0535          24.7900
# 284804       -0.0266          67.8800
# 284805        0.1045          10.0000
# 284806        0.0136         217.0000
#
# [284807 rows x 30 columns]

# %% [markdown]
# Setting our response variable:

# %%
y = df['Target']

# %% [markdown]
# Runnning the resampling (oversampling) method:

# %%
smt = SMOTE()
X, y = smt.fit_resample(X, y)

# %% [markdown]
# Now let's check the results of resampling.

# %%
px.bar(y.value_counts(), color=y.value_counts().index, labels={"value": "Count", "index": "Class"})

# %% [markdown]
# Spliting into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %% [markdown]
# # Creating predictive models for fraud detection in bank transactions

# %% [markdown]
# We'll create three predictive machine learning models to predict bank transaction fraud:
#
# 1. XGBoost
# 2. LightGBM
# 3. Random Forest

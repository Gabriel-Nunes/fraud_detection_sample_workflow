# %% [markdown]
# # 🏦 Detecting Fraud in Bank Transactions
#
# This notebook demonstrates the development of a predictive system for detecting fraudulent bank transactions using machine learning techniques.
# The project aims to simulate a realistic fraud detection workflow — from data generation and preprocessing to model evaluation and interpretation.

# %% [markdown]
# # 1. Objective
#
# The main goal of this project is to build and evaluate a machine learning model capable of identifying potentially fraudulent transactions.
# Through exploratory data analysis (EDA), feature engineering, and supervised learning, we aim to detect patterns that distinguish frauds from legitimate operations.

# %% [markdown]
# ## 2. Importing the libraries

# %% [markdown]
# Importing the main Python libraries for data manipulation, visualization, and machine learning.

# %%
# Basic packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# Data pre-processing packages
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# Machine learning packages
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from xgboost import XGBClassifier

# %% [markdown]
# # 3. Creating fake data

# %% [markdown]
# Since no real dataset is available, we create a synthetic dataset that mimics real-world bank transactions.
# The dataset includes demographic, financial, and behavioral attributes, along with a binary target variable (1 = fraud, 0 = legitimate).

# %% [markdown]
# # 4. Preprocessing

# %% [markdown]
# Data preprocessing includes:
#
# - Handling missing values
# - Removing outliers
# - Normalizing numeric features
# - Encoding categorical variables
# - Selecting the most relevant features
#
# These steps ensure data quality and improve model performance.

# %% [markdown]
# Once the data is prepared, we load it into a pandas DataFrame for further exploration.

# %% [markdown]
# # 5. Loading the Data

# %%
#df = pd.read_csv('data/transferencias.csv')
df = pd.read_csv('data/bank_transactions.csv')
df
# Out:
#         Timestamp  country  city  district  postal_code  ip_address   day  \
# 0            0.00    -1.36 -0.07      2.54         1.38       -0.34  0.46
# 1            0.00     1.19  0.27      0.17         0.45        0.06 -0.08
# 2            1.00    -1.36 -1.34      1.77         0.38       -0.50  1.80
# 3            1.00    -0.97 -0.19      1.79        -0.86       -0.01  1.25
# 4            2.00    -1.16  0.88      1.55         0.40       -0.41  0.10
# ...           ...      ...   ...       ...          ...         ...   ...
# 284802 172,786.00   -11.88 10.07     -9.83        -2.07       -5.36 -2.61
# 284803 172,787.00    -0.73 -0.06      2.04        -0.74        0.87  1.06
# 284804 172,788.00     1.92 -0.30     -3.25        -0.56        2.63  3.03
# 284805 172,788.00    -0.24  0.53      0.70         0.69       -0.38  0.62
# 284806 172,792.00    -0.53 -0.19      0.70        -0.51       -0.01 -0.65
#
#         hour  minute  operating_system  ...  android   ios  purchases  \
# 0       0.24    0.10              0.36  ...    -0.02  0.28      -0.11
# 1      -0.08    0.09             -0.26  ...    -0.23 -0.64       0.10
# 2       0.79    0.25             -1.51  ...     0.25  0.77       0.91
# 3       0.24    0.38             -1.39  ...    -0.11  0.01      -0.19
# 4       0.59   -0.27              0.82  ...    -0.01  0.80      -0.14
# ...      ...     ...               ...  ...      ...   ...        ...
# 284802 -4.92    7.31              1.91  ...     0.21  0.11       1.01
# 284803  0.02    0.29              0.58  ...     0.21  0.92       0.01
# 284804 -0.30    0.71              0.43  ...     0.23  0.58      -0.04
# 284805 -0.69    0.68              0.39  ...     0.27  0.80      -0.16
# 284806  1.58   -0.41              0.49  ...     0.26  0.64       0.38
#
#         browsing_history  relationship  security_index  transaction_time  \
# 0                   0.07          0.13           -0.19              0.13
# 1                  -0.34          0.17            0.13             -0.01
# 2                  -0.69         -0.33           -0.14             -0.06
# 3                  -1.18          0.65           -0.22              0.06
# 4                   0.14         -0.21            0.50              0.22
# ...                  ...           ...             ...               ...
# 284802             -0.51          1.44            0.25              0.94
# 284803             -1.02         -0.61           -0.40              0.07
# 284804              0.64          0.27           -0.09              0.00
# 284805              0.12         -0.57            0.55              0.11
# 284806              0.01         -0.47           -0.82             -0.00
#
#         credit_limit  balance_history  Target
# 0              -0.02           149.62       0
# 1               0.01             2.69       0
# 2              -0.06           378.66       0
# 3               0.06           123.50       0
# 4               0.22            69.99       0
# ...              ...              ...     ...
# 284802          0.82             0.77       0
# 284803         -0.05            24.79       0
# 284804         -0.03            67.88       0
# 284805          0.10            10.00       0
# 284806          0.01           217.00       0
#
# [284807 rows x 31 columns]

# %% [markdown]
# # 6. Exploratory Data Analysis (EDA)

# %% [markdown]
# First, let's check for missing values in the dataset.

# %%
# Checking for missing values
print(df.isna().sum())
# Out:
# Timestamp            0
# country              0
# city                 0
# district             0
# postal_code          0
# ip_address           0
# day                  0
# hour                 0
# minute               0
# operating_system     0
# amount               0
# background           0
# complaints           0
# transaction_count    0
# credit               0
# global_limit         0
# credit_type          0
# merchant             0
# accounts             0
# loans                0
# browser              0
# android              0
# ios                  0
# purchases            0
# browsing_history     0
# relationship         0
# security_index       0
# transaction_time     0
# credit_limit         0
# balance_history      0
# Target               0
# dtype: int64

# %% [markdown]
# Great! There's no missing values in the dataset.
#
# Now, let's check the distribution of the target variable.

# %%
display(df['Target'].value_counts())
px.bar(df['Target'].value_counts(), )
# Out:
# Target
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
(len(df[df['Target'] == 1]) / len(df['Target'])) * 100
# Out:
# 0.1727485630620034

# %% [markdown]
# ⚠️ The dataset is highly imbalanced — only 0.17% of transactions are fraudulent.
# To address this, we’ll apply a resampling strategy (such as SMOTE) before model training, but before that, we will explore feature correlations to identify variables most related to fraud occurrences.

# %%
df.corr()['Target'].sort_values(ascending=False)
# Out:
# Target               1.00
# background           0.15
# postal_code          0.13
# city                 0.09
# android              0.04
# loans                0.03
# browser              0.02
# minute               0.02
# transaction_time     0.02
# credit_limit         0.01
# balance_history      0.01
# security_index       0.00
# relationship         0.00
# ios                  0.00
# purchases           -0.00
# global_limit        -0.00
# transaction_count   -0.00
# browsing_history    -0.01
# Timestamp           -0.01
# day                 -0.04
# ip_address          -0.09
# operating_system    -0.10
# country             -0.10
# accounts            -0.11
# hour                -0.19
# district            -0.19
# credit_type         -0.20
# amount              -0.22
# complaints          -0.26
# credit              -0.30
# merchant            -0.33
# Name: Target, dtype: float64

# %% [markdown]
# > “Postal Code” and “Background” appear to be the most correlated features with the target variable.
#
# This overview helps us detect interdependencies and understand feature distributions.

# %% [markdown]
# # 7. Feature Correlation and Insights
#
# We analyze correlations across all features to identify redundant or irrelevant variables.
# This step is crucial for dimensionality reduction and better model interpretability.

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_43fa5_row0_col0, #T_43fa5_row1_col1, #T_43fa5_row2_col2, #T_43fa5_row3_col3, #T_43fa5_row4_col4, #T_43fa5_row5_col5, #T_43fa5_row6_col6, #T_43fa5_row7_col7, #T_43fa5_row8_col8, #T_43fa5_row9_col9, #T_43fa5_row10_col10, #T_43fa5_row11_col11, #T_43fa5_row12_col12, #T_43fa5_row13_col13, #T_43fa5_row14_col14, #T_43fa5_row15_col15, #T_43fa5_row16_col16, #T_43fa5_row17_col17, #T_43fa5_row18_col18, #T_43fa5_row19_col19, #T_43fa5_row20_col20, #T_43fa5_row21_col21, #T_43fa5_row22_col22, #T_43fa5_row23_col23, #T_43fa5_row24_col24, #T_43fa5_row25_col25, #T_43fa5_row26_col26, #T_43fa5_row27_col27, #T_43fa5_row28_col28, #T_43fa5_row29_col29, #T_43fa5_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col1, #T_43fa5_row1_col5, #T_43fa5_row2_col5, #T_43fa5_row3_col5, #T_43fa5_row4_col5, #T_43fa5_row6_col5, #T_43fa5_row7_col5, #T_43fa5_row8_col5, #T_43fa5_row8_col29, #T_43fa5_row9_col5, #T_43fa5_row10_col5, #T_43fa5_row10_col29, #T_43fa5_row11_col5, #T_43fa5_row12_col5, #T_43fa5_row13_col5, #T_43fa5_row14_col5, #T_43fa5_row15_col5, #T_43fa5_row16_col5, #T_43fa5_row17_col5, #T_43fa5_row18_col5, #T_43fa5_row19_col5, #T_43fa5_row20_col5, #T_43fa5_row21_col5, #T_43fa5_row22_col5, #T_43fa5_row23_col5, #T_43fa5_row24_col5, #T_43fa5_row25_col5, #T_43fa5_row26_col5, #T_43fa5_row27_col5, #T_43fa5_row28_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_43fa5_row0_col2, #T_43fa5_row0_col29, #T_43fa5_row12_col29 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_43fa5_row0_col3, #T_43fa5_row0_col4, #T_43fa5_row0_col6, #T_43fa5_row0_col11, #T_43fa5_row0_col13, #T_43fa5_row0_col15, #T_43fa5_row0_col20, #T_43fa5_row0_col24, #T_43fa5_row0_col25, #T_43fa5_row0_col26, #T_43fa5_row0_col27, #T_43fa5_row0_col28, #T_43fa5_row1_col21, #T_43fa5_row2_col21, #T_43fa5_row2_col29, #T_43fa5_row3_col0, #T_43fa5_row3_col21, #T_43fa5_row4_col21, #T_43fa5_row5_col21, #T_43fa5_row6_col21, #T_43fa5_row7_col21, #T_43fa5_row8_col21, #T_43fa5_row9_col21, #T_43fa5_row10_col21, #T_43fa5_row11_col21, #T_43fa5_row12_col21, #T_43fa5_row13_col21, #T_43fa5_row14_col21, #T_43fa5_row15_col21, #T_43fa5_row16_col21, #T_43fa5_row17_col21, #T_43fa5_row17_col30, #T_43fa5_row18_col21, #T_43fa5_row19_col21, #T_43fa5_row20_col21, #T_43fa5_row22_col21, #T_43fa5_row23_col21, #T_43fa5_row24_col21, #T_43fa5_row25_col21, #T_43fa5_row26_col21, #T_43fa5_row27_col21, #T_43fa5_row28_col21, #T_43fa5_row29_col1, #T_43fa5_row29_col2, #T_43fa5_row29_col5, #T_43fa5_row29_col8, #T_43fa5_row29_col19, #T_43fa5_row29_col22, #T_43fa5_row29_col23, #T_43fa5_row30_col7, #T_43fa5_row30_col9, #T_43fa5_row30_col10, #T_43fa5_row30_col12, #T_43fa5_row30_col14, #T_43fa5_row30_col16, #T_43fa5_row30_col17, #T_43fa5_row30_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_43fa5_row0_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col8, #T_43fa5_row1_col6, #T_43fa5_row1_col13, #T_43fa5_row1_col22, #T_43fa5_row2_col6, #T_43fa5_row2_col13, #T_43fa5_row2_col22, #T_43fa5_row3_col6, #T_43fa5_row3_col13, #T_43fa5_row3_col22, #T_43fa5_row4_col6, #T_43fa5_row4_col13, #T_43fa5_row4_col22, #T_43fa5_row5_col6, #T_43fa5_row5_col13, #T_43fa5_row5_col22, #T_43fa5_row6_col13, #T_43fa5_row6_col22, #T_43fa5_row7_col6, #T_43fa5_row7_col13, #T_43fa5_row7_col22, #T_43fa5_row8_col6, #T_43fa5_row8_col13, #T_43fa5_row8_col22, #T_43fa5_row9_col6, #T_43fa5_row9_col13, #T_43fa5_row9_col22, #T_43fa5_row10_col6, #T_43fa5_row10_col13, #T_43fa5_row10_col22, #T_43fa5_row11_col6, #T_43fa5_row11_col13, #T_43fa5_row11_col22, #T_43fa5_row12_col6, #T_43fa5_row12_col13, #T_43fa5_row12_col22, #T_43fa5_row13_col6, #T_43fa5_row13_col22, #T_43fa5_row14_col6, #T_43fa5_row14_col13, #T_43fa5_row14_col22, #T_43fa5_row15_col6, #T_43fa5_row15_col13, #T_43fa5_row15_col22, #T_43fa5_row16_col6, #T_43fa5_row16_col13, #T_43fa5_row16_col22, #T_43fa5_row17_col6, #T_43fa5_row17_col13, #T_43fa5_row17_col22, #T_43fa5_row18_col6, #T_43fa5_row18_col13, #T_43fa5_row18_col22, #T_43fa5_row19_col6, #T_43fa5_row19_col13, #T_43fa5_row19_col22, #T_43fa5_row20_col6, #T_43fa5_row20_col13, #T_43fa5_row20_col22, #T_43fa5_row21_col6, #T_43fa5_row21_col13, #T_43fa5_row21_col22, #T_43fa5_row22_col6, #T_43fa5_row22_col13, #T_43fa5_row23_col6, #T_43fa5_row23_col13, #T_43fa5_row23_col22, #T_43fa5_row24_col6, #T_43fa5_row24_col13, #T_43fa5_row24_col22, #T_43fa5_row25_col6, #T_43fa5_row25_col13, #T_43fa5_row25_col22, #T_43fa5_row26_col6, #T_43fa5_row26_col13, #T_43fa5_row26_col22, #T_43fa5_row27_col6, #T_43fa5_row27_col13, #T_43fa5_row27_col22, #T_43fa5_row28_col6, #T_43fa5_row28_col13, #T_43fa5_row28_col22, #T_43fa5_row30_col22 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col9, #T_43fa5_row0_col19 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col10, #T_43fa5_row1_col12, #T_43fa5_row2_col12, #T_43fa5_row3_col12, #T_43fa5_row4_col12, #T_43fa5_row5_col12, #T_43fa5_row6_col12, #T_43fa5_row7_col12, #T_43fa5_row8_col12, #T_43fa5_row9_col12, #T_43fa5_row10_col12, #T_43fa5_row11_col12, #T_43fa5_row13_col12, #T_43fa5_row14_col12, #T_43fa5_row15_col12, #T_43fa5_row16_col12, #T_43fa5_row17_col12, #T_43fa5_row18_col12, #T_43fa5_row19_col12, #T_43fa5_row20_col12, #T_43fa5_row21_col12, #T_43fa5_row22_col12, #T_43fa5_row23_col12, #T_43fa5_row24_col12, #T_43fa5_row25_col12, #T_43fa5_row26_col12, #T_43fa5_row27_col12, #T_43fa5_row28_col12 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col12, #T_43fa5_row22_col29 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_43fa5_row0_col14, #T_43fa5_row1_col7, #T_43fa5_row2_col7, #T_43fa5_row3_col7, #T_43fa5_row4_col7, #T_43fa5_row5_col7, #T_43fa5_row6_col7, #T_43fa5_row8_col7, #T_43fa5_row9_col7, #T_43fa5_row10_col7, #T_43fa5_row11_col7, #T_43fa5_row12_col7, #T_43fa5_row13_col7, #T_43fa5_row14_col7, #T_43fa5_row15_col7, #T_43fa5_row16_col7, #T_43fa5_row17_col7, #T_43fa5_row18_col7, #T_43fa5_row19_col7, #T_43fa5_row20_col7, #T_43fa5_row21_col7, #T_43fa5_row22_col7, #T_43fa5_row23_col7, #T_43fa5_row24_col7, #T_43fa5_row25_col7, #T_43fa5_row26_col7, #T_43fa5_row27_col7, #T_43fa5_row28_col7, #T_43fa5_row30_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col16, #T_43fa5_row5_col30, #T_43fa5_row9_col30 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col17, #T_43fa5_row1_col25, #T_43fa5_row2_col25, #T_43fa5_row3_col25, #T_43fa5_row4_col25, #T_43fa5_row5_col25, #T_43fa5_row6_col25, #T_43fa5_row7_col25, #T_43fa5_row8_col25, #T_43fa5_row9_col25, #T_43fa5_row10_col25, #T_43fa5_row11_col25, #T_43fa5_row12_col25, #T_43fa5_row13_col25, #T_43fa5_row14_col25, #T_43fa5_row15_col25, #T_43fa5_row16_col25, #T_43fa5_row17_col25, #T_43fa5_row18_col25, #T_43fa5_row19_col25, #T_43fa5_row20_col25, #T_43fa5_row21_col25, #T_43fa5_row22_col25, #T_43fa5_row23_col25, #T_43fa5_row24_col25, #T_43fa5_row26_col25, #T_43fa5_row27_col25, #T_43fa5_row28_col25 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col18 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col21, #T_43fa5_row30_col26 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col22, #T_43fa5_row1_col11, #T_43fa5_row1_col29, #T_43fa5_row2_col11, #T_43fa5_row3_col11, #T_43fa5_row4_col11, #T_43fa5_row5_col11, #T_43fa5_row6_col11, #T_43fa5_row7_col11, #T_43fa5_row8_col11, #T_43fa5_row9_col11, #T_43fa5_row10_col11, #T_43fa5_row12_col11, #T_43fa5_row13_col11, #T_43fa5_row14_col11, #T_43fa5_row15_col11, #T_43fa5_row16_col11, #T_43fa5_row17_col11, #T_43fa5_row18_col11, #T_43fa5_row19_col11, #T_43fa5_row20_col11, #T_43fa5_row21_col11, #T_43fa5_row22_col11, #T_43fa5_row23_col11, #T_43fa5_row24_col11, #T_43fa5_row25_col11, #T_43fa5_row26_col11, #T_43fa5_row27_col11, #T_43fa5_row28_col11, #T_43fa5_row29_col11, #T_43fa5_row29_col12 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_43fa5_row0_col23, #T_43fa5_row29_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_43fa5_r

# %% [markdown]
# This overview is important to detect interdependencies between variables and understand the data distribution. In this case, we can see that our most interesting variables are does not have a strong correlation with each other or with other variables, what could give us multicollinarity problems.

# %% [markdown]
# # 8. Preparing data for training

# %% [markdown]
# Given the severe class imbalance, we use SMOTE (Synthetic Minority Oversampling Technique) to generate synthetic samples of the minority class, ensuring a balanced training dataset.

# %% [markdown]
# ### Spliting data into train and test
# Setting our explanatory variables:

# %%
X = df.drop(['Target'], axis=1)
X
# Out:
#         Timestamp  country  city  district  postal_code  ip_address   day  \
# 0            0.00    -1.36 -0.07      2.54         1.38       -0.34  0.46
# 1            0.00     1.19  0.27      0.17         0.45        0.06 -0.08
# 2            1.00    -1.36 -1.34      1.77         0.38       -0.50  1.80
# 3            1.00    -0.97 -0.19      1.79        -0.86       -0.01  1.25
# 4            2.00    -1.16  0.88      1.55         0.40       -0.41  0.10
# ...           ...      ...   ...       ...          ...         ...   ...
# 284802 172,786.00   -11.88 10.07     -9.83        -2.07       -5.36 -2.61
# 284803 172,787.00    -0.73 -0.06      2.04        -0.74        0.87  1.06
# 284804 172,788.00     1.92 -0.30     -3.25        -0.56        2.63  3.03
# 284805 172,788.00    -0.24  0.53      0.70         0.69       -0.38  0.62
# 284806 172,792.00    -0.53 -0.19      0.70        -0.51       -0.01 -0.65
#
#         hour  minute  operating_system  ...  browser  android   ios  \
# 0       0.24    0.10              0.36  ...     0.25    -0.02  0.28
# 1      -0.08    0.09             -0.26  ...    -0.07    -0.23 -0.64
# 2       0.79    0.25             -1.51  ...     0.52     0.25  0.77
# 3       0.24    0.38             -1.39  ...    -0.21    -0.11  0.01
# 4       0.59   -0.27              0.82  ...     0.41    -0.01  0.80
# ...      ...     ...               ...  ...      ...      ...   ...
# 284802 -4.92    7.31              1.91  ...     1.48     0.21  0.11
# 284803  0.02    0.29              0.58  ...     0.06     0.21  0.92
# 284804 -0.30    0.71              0.43  ...     0.00     0.23  0.58
# 284805 -0.69    0.68              0.39  ...     0.13     0.27  0.80
# 284806  1.58   -0.41              0.49  ...     0.38     0.26  0.64
#
#         purchases  browsing_history  relationship  security_index  \
# 0           -0.11              0.07          0.13           -0.19
# 1            0.10             -0.34          0.17            0.13
# 2            0.91             -0.69         -0.33           -0.14
# 3           -0.19             -1.18          0.65           -0.22
# 4           -0.14              0.14         -0.21            0.50
# ...           ...               ...           ...             ...
# 284802       1.01             -0.51          1.44            0.25
# 284803       0.01             -1.02         -0.61           -0.40
# 284804      -0.04              0.64          0.27           -0.09
# 284805      -0.16              0.12         -0.57            0.55
# 284806       0.38              0.01         -0.47           -0.82
#
#         transaction_time  credit_limit  balance_history
# 0                   0.13         -0.02           149.62
# 1                  -0.01          0.01             2.69
# 2                  -0.06         -0.06           378.66
# 3                   0.06          0.06           123.50
# 4                   0.22          0.22            69.99
# ...                  ...           ...              ...
# 284802              0.94          0.82             0.77
# 284803              0.07         -0.05            24.79
# 284804              0.00         -0.03            67.88
# 284805              0.11          0.10            10.00
# 284806             -0.00          0.01           217.00
#
# [284807 rows x 30 columns]

# %% [markdown]
# Setting our response variable:

# %%
y = df['Target']

# %% [markdown]
# Runnning the resampling (oversampling) method:

# %%
smt = SMOTE()
X, y = smt.fit_resample(X_train, y_train)

# %% [markdown]
# Now let's check the results of resampling.

# %%
px.bar(y.value_counts(), color=y.value_counts().index, labels={"value": "Count", "index": "Class"})

# %% [markdown]
# # 9. Creating predictive models for fraud detection in bank transactions

# %% [markdown]
# We train multiple machine learning models, such as:
#
# - Random Forest
# - XGBoost
# - LightGBM
#
# Each model is evaluated based on its ability to correctly classify fraudulent transactions while minimizing false positives.
#
#
# ### Model Evaluation
#
# We use a combination of the following metrics to assess model performance:
#
# - Confusion Matrix
# - Precision, Recall, and F1-Score
# - ROC–AUC Curve (not implemented yet)
#
# Because fraud detection is a highly imbalanced problem, **precision** are more important than overall accuracy. Moreover, the best model should balance sensitivity (detecting frauds) and specificity (avoiding false alarms), so we gave a higher attention to Confusion Matrix and **F1-Score** reports.

# %% [markdown]
# ## 9.1 XGBoost

# %% [markdown]
# Building the model

# %%
model = XGBClassifier()

# %% [markdown]
# Training the model to detect fraud in bank transactions (can take a while)

# %%
model = model.fit(X_train, y_train)
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Using the real values to create a prediction dataset

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(85443,))

# %% [markdown]
# Comparing model answers with real data prediction.
#
# Let's create a template dataframe with desired answers and our model answers.

# %%
template  = pd.DataFrame({'template': y_test, 'predictions': y_predict})
template
# Out:
# Sample of the template:
#         template  predictions
# 338226         1            1
# 318644         1            1
# 431631         1            1
# 381828         1            1
# 466931         1            1
# ...          ...          ...
# 316720         1            1
# 171658         0            0
# 530325         1            1
# 450324         1            1
# 519278         1            1
#
# [170589 rows x 2 columns]

# %% [markdown]
# At the first sight, looks like our model did a good job!
#
# Using some metrics to evaluate our model:

# %%
print(f'Accuracy: \n{accuracy_score(y_test, y_predict)}')
# Out:
# Accuracy:
# 0.9994733330992591

# %% [markdown]
# In terms of accuracy, our model is great. Considering the imbalanced dataset, this is a very good result. To confirm, let's check the classification report.

# %%
print(f'Classification metrics: \n{classification_report(y_test, y_predict)}')
# Out:
# Classification metrics:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85288
#            1       0.88      0.83      0.85       155
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.91      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# The classification report confirms our high accuracy level.
#
# Finally we can run a confusion matrix to see the true positive and false positive rates.

# %%
print(f'Confusion matrix: \n{confusion_matrix(y_test, y_predict)}')
# Out:
# Confusion matrix:
# [[85270    18]
#  [   27   128]]

# %% [markdown]
# The main diagonal in our confusion matrix shows the number of correct predictions. The off-diagonal elements represent incorrect predictions. Our model brought us only 30 incorrect predictions in positive cases.

# %% [markdown]
# ## 9.2 LightGBM

# %% [markdown]
# Setting the model

# %%
# LightGBM
train_data = lgb.Dataset(X_train, label=y_train)

# Setting parameters for lightgbm
params = {
    'num_leaves': 1000,
    'objective': 'binary',
    'max_depth': 7,
    'learning_rate': .01,
    'max_bin': 200,
    'metric': ['auc', 'binary_logloss']
}

# %% [markdown]
# Training our model using lightgbm

# %%
num_round = 50

lgbm = lgb.train(params, train_data, num_round)
# Out:
# [LightGBM] [Info] Number of positive: 337, number of negative: 199027
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008620 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6000
# [LightGBM] [Info] Number of data points in the train set: 199364, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001690 -> initscore=-6.381113
# [LightGBM] [Info] Start training from score -6.381113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# Testing the model

# %%
y_predict = lgbm.predict(X_test)

# %% [markdown]
# Evaluating the results

# %%
template = pd.DataFrame({'template': y_test, 'predictions': y_predict})
template
# Out:
#         template  predictions
# 86801          0         0.00
# 34867          0         0.00
# 151239         0         0.00
# 122560         0         0.00
# 77820          0         0.00
# ...          ...          ...
# 11519          0         0.00
# 21449          0         0.00
# 129577         0         0.00
# 197268         0         0.00
# 11802          0         0.00
#
# [85443 rows x 2 columns]

# %% [markdown]
# LightGBM returns probabilities. So we have to transform it to binary values setting a threshold

# %%
y_predict.size
# Out:
# 85443

# %%
# Converting probabilities into 0 or 1
for i in range(0, y_predict.size):
    if y_predict[i] >= 0.5:
        y_predict[i] = 1
    else:
        y_predict[i] = 0

# %%
pd.value_counts(y_predict)
# Out:
# 0.00    85350
# 1.00       93
# Name: count, dtype: int64

# %% [markdown]
# Now we have only zeros and ones.

# %% [markdown]
# Evaluating the model

# %%
print('Classification metrics: \n', classification_report(y_test, y_predict))
print('Accuracy: \n', accuracy_score(y_test, y_predict))
print('\nConfusion matrix: \n', confusion_matrix(y_test, y_predict))
# Out:
# Classification metrics:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85288
#            1       0.94      0.56      0.70       155
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.78      0.85     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Accuracy:
#  0.999133925541004
#
# Confusion matrix:
#  [[85282     6]
#  [   68    87]]

# %%
# LightGBM
train_data = lgb.Dataset(X_train, label=y_train)

# Setting parameters for lightgbm
params = {
    'num_leaves': 1000,
    'objective': 'binary',
    'max_depth': 7,
    'learning_rate': .01,
    'max_bin': 200,
    'metric': ['auc', 'binary_logloss']
}

# %% [markdown]
# Training our model using lightgbm

# %%
num_round = 50

lgbm = lgb.train(params, train_data, num_round)
# Out:
# [LightGBM] [Info] Number of positive: 337, number of negative: 199027
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028663 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6000
# [LightGBM] [Info] Number of data points in the train set: 199364, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001690 -> initscore=-6.381113
# [LightGBM] [Info] Start training from score -6.381113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# Testing the model

# %%
y_predict = lgbm.predict(X_test)

# %% [markdown]
# Evaluating the results

# %%
template = pd.DataFrame({'template': y_test, 'predictions': y_predict})
template
# Out:
#         template  predictions
# 86801          0     0.001027
# 34867          0     0.001027
# 151239         0     0.001143
# 122560         0     0.001027
# 77820          0     0.001027
# ...          ...          ...
# 11519          0     0.001066
# 21449          0     0.001027
# 129577         0     0.001027
# 197268         0     0.001089
# 11802          0     0.001066
#
# [85443 rows x 2 columns]

# %% [markdown]
# LightGBM returns probabilities. So we have to transform it to binary values setting a threshold

# %%
y_predict.size
# Out:
# 85443

# %%
# Converting probabilities into 0 or 1
for i in range(0, y_predict.size):
    if y_predict[i] >= 0.5:
        y_predict[i] = 1
    else:
        y_predict[i] = 0

# %%
pd.value_counts(y_predict)
# Out:
# 0.0    85350
# 1.0       93
# Name: count, dtype: int64

# %% [markdown]
# Now we have only zeros and ones.

# %% [markdown]
# Evaluating the model

# %%
print('Classification metrics: \n', classification_report(y_test, y_predict))
print('Accuracy: \n', accuracy_score(y_test, y_predict))
print('\nConfusion matrix: \n', confusion_matrix(y_test, y_predict))
# Out:
# Classification metrics:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85288
#            1       0.94      0.56      0.70       155
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.78      0.85     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Accuracy:
#  0.999133925541004
#
# Confusion matrix:
#  [[85282     6]
#  [   68    87]]

# %% [markdown]
# ## 9.2 Random Forest

# %% [markdown]
# Setting up the model

# %%
model = RandomForestClassifier()

# %% [markdown]
# Training the model

# %%
model = model.fit(X_train, y_train)
model
# Out:
# RandomForestClassifier()

# %% [markdown]
# Testing the model

# %%
y_predict = model.predict(X_test)

# %% [markdown]
# Evaluating the model

# %%
template = pd.DataFrame({'template': y_test, 'prediction': y_predict})
template
# Out:
#         template  prediction
# 86801          0           0
# 34867          0           0
# 151239         0           0
# 122560         0           0
# 77820          0           0
# ...          ...         ...
# 11519          0           0
# 21449          0           0
# 129577         0           0
# 197268         0           0
# 11802          0           0
#
# [85443 rows x 2 columns]

# %%
# Getting the metrics
print('Classification metrics: \n', classification_report(y_test, y_predict))
print('Accuracy: \n', accuracy_score(y_test, y_predict))
print('Confusion Matrix: \n', confusion_matrix(y_test, y_predict))
# Out:
# Classification metrics:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85288
#            1       0.93      0.83      0.88       155
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443
#
# Accuracy:
#  0.9995903701883126
# Confusion Matrix:
#  [[85279     9]
#  [   26   129]]

# %% [markdown]
# Conclusion

# %% [markdown]
# - Hypotesys generation is crucial for fraud detection.
# - Unbalanced classes must be handled.
# - Sometimes much simple algorithms are better than complex ones. Random Forest beated LightGBM and XGBoost, but processing time was much higher.
